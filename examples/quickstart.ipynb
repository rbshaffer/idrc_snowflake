# %% [markdown]
# ## Overview
#
# This notebook is intended as a simple quickstart template, to get users up and running in the IDR. For the purposes of this guide, we assume:
# 1. You're planning to execute this notebook locally, on a CMS-issued laptop.
# 2. You have all necessary job codes to access the IDR and any relevant data assets.
# 3. You've already installed the [Python Snowflake connector](https://docs.snowflake.com/en/developer-guide/python-connector/python-connector-install).
# 4. Your client laptop or VM image has a web browser installed.
#
# For the purposes of this notebook, we leave the Snowflake role unspecified, which implicitly uses your default IDR Snowflake role and warehouse. If you need to specify a role and/or warehouse for the queries you wish to run, see the README for details.
#
# As mentioned in the README, be careful not to download too many records to your local computer. Try to conduct all aggregations and calculations in the IDR's Snowflake instance, and download aggregated or summarized results to your local machine.

# %%
import snowflake.connector

# Fill in your EUA ID below
ctx = snowflake.connector.connect(
          account="cms-idr.privatelink",
          user="<your_eua>",
          authenticator="externalbrowser"
    )
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Going to open: https://idm.cms.gov/app/snowflake/exk7te50lbXzhiDpV297/sso/saml?SAMLRequest=lZJdb9owGIX%2FSuRdJ3ZSGMUiVKwoGhNfgrTqeucmBiwcO%2Fh1Esqvn8PH1F200u4i5xw%2Fx%2B95Bw%2FHQno1NyC0ilEYEORxlelcqG2MntLEv0ceWKZyJrXiMXrngB6GA2CFLOmosju14oeKg%2FXcRQpo%2ByNGlVFUMxBAFSs4UJvR9Wg2pVFAKAPgxjoculpyEI61s7akGDdNEzR3gTZbHBFCMOljp2ol39AHRPk1ozTa6kzLm%2BXo3vQJIsSk0yKcwhGWV%2BMPoS4j%2BIrydhEB%2FZmmS3%2B5WKfIG91e96gVVAU3a25qkfGn1fQSAFyCrABf5CYojaiZ5VKofQBKNxvJ9jzTRVlZd2%2FgvvCG51jqrXDTmoxjVO5Fnuxfjqfj4sBEONvN6kTmvV%2F1a7L5%2FZ01Y5NOVwe2OC2T%2Bdx2MuQ937qN2m4nABWfqLZR645I1PVJ6N%2BFadilnXtKoqBz339F3tg1KhSzZ%2BcttsiLwEUPtrrGrCzx38iYH%2Fc9y7tEvr2cdmJcPkf9HgbQuO0KXdaFntlm%2BP9DGOCP%2FuvuzV0dk%2FFSS5G9e4k2BbOftxUG4flE5P7mLKW8YEKO8txwANealLp5NNzliJE1FUd4eKH%2Bu%2BTDPw%3D%3D&RelayState=ver%3A1-hint%3A4522773949202-ETMsDgAAAZS9DDk5ABRBRVMvQ0JDL1BLQ1M1UGFkZGluZwEAABAAEBrQHFHzqQlRfsm0fR4i0sQAAACAw8VsX0GAJ%2FIFErGUy9y051FCtJxoisiovCpH6y4Clym9jJbUGfhEKo8%2Bhoe4%2BcVaCV%2F2P52les80fXUpfHwvMlptO2yuEi2dNuFaUPq0wy5AhiHOaZgCa%2FJe%2B1w2kuwIGZ8WWuydrQqZW1zQWt4Brxfdoj2fewA%2BC3u%2FyPGwdiMAFHVFWaQgUZ8PXml1IJ1bUabumt7Z to authenticate...

# %%
query = """
    select geo_zip5_cd
    , count(1)
    from idrc_prd.cms_vdm_view_mdcr_prd.v2_mdcr_bene
    where idr_ltst_trans_flg = 'Y'
    and idr_trans_obslt_ts > current_date()
    and (bene_death_dt is null or bene_death_dt > current_date())
    group by geo_zip5_cd
"""

# %%
with ctx.cursor() as cur:
    cur.execute(query)
    df = cur.fetch_pandas_all()

# %%
# print the first five rows to verify
df[0:5]
# Out:
#   GEO_ZIP5_CD  COUNT(1)
# 0       80920      6639
# 1       60190      2973
# 2       70131      4995
# 3       91343      9103
# 4       91740      5537
